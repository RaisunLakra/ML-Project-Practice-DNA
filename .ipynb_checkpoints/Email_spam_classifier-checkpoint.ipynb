# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

# %% [markdown]
# # Load datasets

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("venky73/spam-mails-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/user/.cache/kagglehub/datasets/venky73/spam-mails-dataset/versions/1

# %%
# !ls '/home/user/.cache/kagglehub/datasets/venky73/spam-mails-dataset/versions/1'
# Out:
# spam_ham_dataset.csv

# %%
df = pd.read_csv('/home/user/.cache/kagglehub/datasets/venky73/spam-mails-dataset/versions/1/spam_ham_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 label                                               text  \
# 0         605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1        2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2        3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3        4685  spam  Subject: photoshop , windows , office . cheap ...
# 4        2030   ham  Subject: re : indian springs\r\nthis deal is t...
#
#    label_num
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0

# %%
num_row, num_col = df.shape
print(num_row, num_col)
# Out:
# 5171 4

# %% [markdown]
# # Data Cleaning and preprocessing

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# label         0
# text          0
# label_num     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'label', 'text', 'label_num'], dtype='object')

# %%
df = df.drop(columns = {'Unnamed: 0', 'label'})

# %%
print(df.isna().sum(), df.duplicated().sum())
# Out:
# text         0
# label_num    0
# dtype: int64 178

# %% [markdown]
# # Split data into train and test data

# %%
df = df.sample(frac=1)

# %%
df.head()
# Out:
#       Unnamed: 0 label                                               text  \
# 3206        1158   ham  Subject: 98 - 6892 ( sitara deal 319063 )\r\nt...
# 720         4247  spam  Subject: looking for love ? tonight ?\r\nthis ...
# 1140        1696   ham  Subject: eastrans nomination change effective ...
# 370         4729  spam  Subject: 10 stuff better than v i a g r a\r\nh...
# 1873        3476   ham  Subject: 9 / 12 / 01 neon lesson\r\n- neon - s...
#
#       label_num
# 3206          0
# 720           1
# 1140          0
# 370           1
# 1873          0

# %%
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#    Unnamed: 0 label                                               text  \
# 0        1158   ham  Subject: 98 - 6892 ( sitara deal 319063 )\r\nt...
# 1        4247  spam  Subject: looking for love ? tonight ?\r\nthis ...
# 2        1696   ham  Subject: eastrans nomination change effective ...
# 3        4729  spam  Subject: 10 stuff better than v i a g r a\r\nh...
# 4        3476   ham  Subject: 9 / 12 / 01 neon lesson\r\n- neon - s...
#
#    label_num
# 0          0
# 1          1
# 2          0
# 3          1
# 4          0

# %%
X = df['text'].rename('Email_text')
Y = df['label_num'].rename('target')

# %%
n = round(num_row*0.8)
print(n)
# Out:
# 4137

# %%
X_train, Y_train = X[0:n], Y[0:n]
X_test, Y_test = X[n:], Y[n:]

# %%
X_train.tail()
# Out:
# 4132    Subject: pipeline nominations away from the of...
# 4133    Subject: inkjet , laser charset = us - ascii "...
# 4134    Subject: conoco supply cuts on oasis 5 / 21 - ...
# 4135    Subject: your mother may find out\r\nremove\r\...
# 4136    Subject: tenaska agreement\r\ndarren ,\r\ndo y...
# Name: Email_text, dtype: object

# %%
X_test.head()
# Out:
# 4137    Subject: re : valero rfp issued june 1 , 2001\...
# 4138    Subject: shower your lover ( s ) with a founta...
# 4139    Subject: csgu to launch 13 videos\r\nmultimedi...
# 4140    Subject: eol application id and password\r\nda...
# 4141    Subject: re : meter # 1512\r\nno one resolved ...
# Name: Email_text, dtype: object

# %%
print(len(X_train), len(X_test))
# Out:
# 4137 1034

# %% [markdown]
# # Extract Features

# %%
cv = CountVectorizer()

# %%
features_train = cv.fit_transform(X_train)

# %%
features_test = cv.transform(X_test)

# %% [markdown]
# # Modeling

# %%
model = SVC()

# %%
model.fit(features_train, Y_train)
# Out:
# SVC()

# %% [markdown]
# # Test Accuracy

# %%
print('Accuracy of our model:', model.score(features_test, Y_test))
# Out:
# Accuracy of our model: 0.9613152804642167

# %% [markdown]
# # Optimization

# %%
tuned_parameters = {'kernel': ['linear', 'rbf'],
                    'gamma': [1e-3, 1e-4],
                    'C': [1, 10, 100, 1000]}
best_model = GridSearchCV(SVC(), tuned_parameters)

# %%
best_model.fit(features, Y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001],
#                          'kernel': ['linear', 'rbf']})

# %%
best_model.best_params_
# Out:
# {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}

# %% [markdown]
# # Test Accuracy of Optimized Model

# %%
print('Accuracy of Optimized model:', best_model.score(features_test, Y_test))
# Out:
# Accuracy of Optimized model: 0.9709864603481625

# %% [markdown]
# # Conclusion
#     Accuracy increased after applying GridSearchCV from 0.9613152804642167 to 0.9709864603481625

# %% [markdown]
# # Confusion Matric

# %%
y_predict = best_model.predict(features_test)

# %%
cm = confusion_matrix(Y_test, y_predict)
# sklearn.metrics.confusion_matrix(y_true, y_pred, *, labels=None, sample_weight=None, normalize=None)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.xlabel('Predicted Value')
plt.ylabel('ActualValue')
plt.show()
